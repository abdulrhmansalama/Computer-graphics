# %%
import circles as c
import lines as l
import Transformations as tr

# %%
import importlib

import Transformations
import circles
import lines

importlib.reload(lines)
importlib.reload(circles)
importlib.reload(Transformations)
# Out:
# <module 'Transformations' from 'c:\\Users\\LAP TECHNOLOGY\\Desktop\\computer graphics\\Transformations.py'>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
points = l.dda(0, 0, 10, 10)

x_vals = [p[0] for p in points]
y_vals = [p[1] for p in points]

plt.scatter(x_vals, y_vals)


plt.xlim(-20, 20)
plt.ylim(-20, 20)
plt.grid()

plt.show()

# %%
points = c.midpoint_circle(0, 0,100000)   

x_vals = [p[0] for p in points]
y_vals = [p[1] for p in points]

plt.scatter(x_vals, y_vals, s=20)


plt.gca().set_aspect('equal')   
plt.grid()

plt.show()

# %%
full_circle = c.expand_circle(points, 0, 0)

x_vals = [p[0] for p in full_circle]
y_vals = [p[1] for p in full_circle]

plt.scatter(x_vals, y_vals)
plt.gca().set_aspect('equal')
plt.grid()
plt.show()

# %%
points = c.midpoint_ellipse(0, 0, 10, 5)

x_vals = [p[0] for p in points]
y_vals = [p[1] for p in points]

plt.scatter(x_vals, y_vals)

plt.gca().set_aspect('equal')
plt.grid()
plt.show()

# %%
import Transformations as tr



p = (2, 3)

print(tr.translate_2d(p, 5, -2))   
print(tr.scale_2d(p, 2, 3))        
print(tr.rotate_2d(p, 90))         

p3 = (1, 2, 3)
print(tr.translate_3d(p3, 1, 1, 1))
print(tr.rotate_z(p3, 90))
# Out:
# (7, 1)
# (4, 9)
# (-3.0, 2.0)
# (2, 3, 4)
# (-2.0, 1.0000000000000002, 3)
